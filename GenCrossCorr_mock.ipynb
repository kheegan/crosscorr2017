# %% [markdown]
# # Measuring the Galaxy-LyaForest Cross-Correlation from Mock Samples
#
# Here, we calculate the all the Galaxy-Forest cross-correlation in the TreePM256 simulation mocks
#
# Largely adapted from crosscorr_cl2017.ipynb
#
# ### Read in Ly-a forest pixels

# %%
import numpy as np
import time as time
import lyafxcorr_kg as xcorr

# Set up matplotlib and use a nicer set of plot parameters
# %config InlineBackend.rc = {}
import matplotlib as mpl
mpl.rc('mathtext',fontset='stixsans')
mpl.rc('figure', facecolor="white")
#matplotlib.rc_file("../../templates/matplotlibrc")
import matplotlib.pyplot as plt
#import matplotlib.colors as colors
# %matplotlib inline

from astropy.cosmology import FlatLambdaCDM
from astropy.io import fits
from astropy.io import ascii
from astropy.table import Table
from astropy import units as u
from astropy.coordinates import SkyCoord

# Define cosmology
cosmo = FlatLambdaCDM(H0=70, Om0=0.31)

mockdir = '/Users/kheegan/lya/3d_recon/map2017/crosscorr/mocks/'

# %% [markdown]
# ## Read in bin edges

# %%
PiBin_fil = 'bins23_pi_0-30hMpc.txt'
SigBin_fil = 'bins10_sigma_0-30hMpc.txt'

PiBins0 = ascii.read(PiBin_fil)
SigBins0 = ascii.read(SigBin_fil)

PiEdges = PiBins0['pi_edges'].data
SigEdges = SigBins0['sigma_edges'].data

# Convert bin boundaries from Mpc/h to Mpc
PiEdges  = PiEdges/(len(PiEdges)*[cosmo.h])
SigEdges = SigEdges/(len(SigEdges)*[cosmo.h])

print('Pi bin edges in Mpc:')
print(PiEdges)
print('Sigma bin edges in Mpc:')
print(SigEdges)


PiBound = (min(PiEdges), max(PiEdges) )
# Out:
# Pi bin edges in Mpc:
# [-42.85714286 -35.71428571 -30.         -24.28571429 -18.57142857
#  -14.28571429 -10.          -7.14285714  -5.          -2.85714286
#   -1.42857143  -0.35714286   0.35714286   1.42857143   2.85714286
#    5.           7.14285714  10.          14.28571429  18.57142857
#   24.28571429  30.          35.71428571  42.85714286]
# Sigma bin edges in Mpc:
# [ 0.          1.          2.14285714  3.57142857  5.71428571 10.
#  14.28571429 21.42857143 32.14285714 42.85714286]

# %%
for ifile in np.arange(1,81):

    tstart = time.time()
    filesuffix = '{0:03d}'.format(ifile)

    lyafil = mockdir+'pixel_radecz_mock_'+filesuffix+'.bin'
    lyapix = xcorr.lyapix(lyafil,cosmo=cosmo)

    print("Read in {0:d} Ly-a forest pixels from mock {1:03d}".format(lyapix.npix, 
                                                                      ifile))
    
    npix = lyapix.npix

    ### Read in galaxies 
    # We use the catalog created with Create_GalzMocks.IPYNB

    galfil = mockdir+'cat_galmock_nonuniq_'+filesuffix+'.dat'

    gal = ascii.read(galfil, format='ipac')
    #print(gal.columns)

    gal_3d = gal[gal['source'] == '3DHST']
    gal_zD = gal[gal['source'] == 'zDeep']
    gal_mosdef = gal[gal['source'] == 'MOSDEF']
    gal_vuds = gal[gal['source']=='VUDS']
    gal_clamato=gal[gal['source']=='CLAMATO']

    print('Read in %i 3D-HST galaxies, %i zCOSMOS-Deep galaxies, %i MOSDEF galaxies,' 
          '%i VUDS galaxies, %i CLAMATO galaxies' % 
          (len(gal_3d), len(gal_zD), len(gal_mosdef), len(gal_vuds),len(gal_clamato)) )

    # Convert to 3D Sky positions
    Coord_3d     = SkyCoord(ra=gal_3d['ra']  , dec=gal_3d['dec']  ,
                      distance=cosmo.comoving_distance(gal_3d['zspec']))
    Coord_zD     = SkyCoord(ra=gal_zD['ra']  , dec=gal_zD['dec']  ,
                       distance=cosmo.comoving_distance(gal_zD['zspec']))
    Coord_mosdef = SkyCoord(ra=gal_mosdef['ra']  , dec=gal_mosdef['dec']  ,
                       distance=cosmo.comoving_distance(gal_mosdef['zspec']))
    Coord_vuds   = SkyCoord(ra=gal_vuds['ra']  , dec=gal_vuds['dec']  ,
                           distance=cosmo.comoving_distance(gal_vuds['zspec']))
    Coord_clamato=SkyCoord(ra=gal_clamato['ra'], dec=gal_clamato['dec']  ,
                          distance=cosmo.comoving_distance(gal_clamato['zspec']))
    Coord_all = SkyCoord(ra=gal['ra'], dec=gal['dec']  ,
                          distance=cosmo.comoving_distance(gal['zspec']))


    # Compute Cross-Correlation For MOSDEF Galaxies
    XCorr_mosdef, NoXCorr_mosdef = xcorr.xcorr_gal_lya(Coord_mosdef, 
                                                       lyapix, SigEdges, PiEdges, 
                                                       cosmo=cosmo, verbose=0)

    # Compute Cross-Correlation For zCOSMOS-Deep Galaxies
    XCorr_zD, NoXCorr_zD = xcorr.xcorr_gal_lya(Coord_zD, lyapix, 
                                               SigEdges, PiEdges,cosmo=cosmo, verbose=0)


    # Compute Cross-Correlation for CLAMATO Galaxies
    XCorr_clamato, NoXCorr_clamato = xcorr.xcorr_gal_lya(Coord_clamato, lyapix, 
                                                         SigEdges, PiEdges,cosmo=cosmo,
                                                        verbose=0)

    # Compute Cross-Correlation For 3D-HST Galaxies
    XCorr_3d, NoXCorr_3d = xcorr.xcorr_gal_lya(Coord_3d, lyapix, 
                                               SigEdges, PiEdges, cosmo=cosmo, verbose=0)


    # Compute Cross-Correlations for VUDS galaxies
    XCorr_vuds, NoXCorr_vuds = xcorr.xcorr_gal_lya(Coord_vuds, lyapix, 
                                                   SigEdges, PiEdges, cosmo=cosmo, 
                                                   verbose=0)
    
    np.save(mockdir+"crosscorr/xcorrmock_3dhst_"+filesuffix+"_v4.1.npy", XCorr_3d)
    np.save(mockdir+"crosscorr/xcorrmock_zDeep_"+filesuffix+"_v4.1.npy", XCorr_zD)
    np.save(mockdir+"crosscorr/xcorrmock_mosdef_"+filesuffix+"_v4.1.npy", XCorr_mosdef)
    np.save(mockdir+"crosscorr/xcorrmock_vuds_"+filesuffix+"_v4.1.npy", XCorr_vuds)
    np.save(mockdir+"crosscorr/xcorrmock_clamato_"+filesuffix+"_v4.1.npy", XCorr_vuds)

    if ifile ==1:    
        print('Time to generate one mock = {0}s'.format(time.time()-tstart))
# Out:
# Read in 74714 Ly-a forest pixels from mock 001
# Read in 251 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 177 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Time to generate one mock = 32.98867201805115s
# Read in 78603 Ly-a forest pixels from mock 002
# Read in 277 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 191 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 77868 Ly-a forest pixels from mock 003
# Read in 266 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 182 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 72872 Ly-a forest pixels from mock 004
# Read in 290 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 193 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 78184 Ly-a forest pixels from mock 005
# Read in 304 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 193 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 66005 Ly-a forest pixels from mock 006
# Read in 235 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 180 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 80069 Ly-a forest pixels from mock 007
# Read in 260 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 188 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 76296 Ly-a forest pixels from mock 008
# Read in 247 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 179 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 69007 Ly-a forest pixels from mock 009
# Read in 303 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 191 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 73247 Ly-a forest pixels from mock 010
# Read in 246 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 185 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 79865 Ly-a forest pixels from mock 011
# Read in 240 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 177 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 75832 Ly-a forest pixels from mock 012
# Read in 284 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 193 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 70445 Ly-a forest pixels from mock 013
# Read in 294 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 190 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 82072 Ly-a forest pixels from mock 014
# Read in 305 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 74132 Ly-a forest pixels from mock 015
# Read in 278 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 190 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 84485 Ly-a forest pixels from mock 016
# Read in 274 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 190 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 76486 Ly-a forest pixels from mock 017
# Read in 291 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 79064 Ly-a forest pixels from mock 018
# Read in 250 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 184 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 75627 Ly-a forest pixels from mock 019
# Read in 308 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 75464 Ly-a forest pixels from mock 020
# Read in 312 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 71103 Ly-a forest pixels from mock 021
# Read in 265 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 186 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 80127 Ly-a forest pixels from mock 022
# Read in 251 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 190 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 77767 Ly-a forest pixels from mock 023
# Read in 267 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 189 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 79384 Ly-a forest pixels from mock 024
# Read in 238 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 181 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 69303 Ly-a forest pixels from mock 025
# Read in 262 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 187 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 76085 Ly-a forest pixels from mock 026
# Read in 248 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 176 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 74412 Ly-a forest pixels from mock 027
# Read in 259 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 190 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 76355 Ly-a forest pixels from mock 028
# Read in 251 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 181 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 83276 Ly-a forest pixels from mock 029
# Read in 297 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 73868 Ly-a forest pixels from mock 030
# Read in 287 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 191 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 76256 Ly-a forest pixels from mock 031
# Read in 319 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 73498 Ly-a forest pixels from mock 032
# Read in 282 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 191 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 74548 Ly-a forest pixels from mock 033
# Read in 269 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 189 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 72146 Ly-a forest pixels from mock 034
# Read in 289 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 191 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 78753 Ly-a forest pixels from mock 035
# Read in 298 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 193 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 78509 Ly-a forest pixels from mock 036
# Read in 276 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 189 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 72190 Ly-a forest pixels from mock 037
# Read in 303 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 76280 Ly-a forest pixels from mock 038
# Read in 284 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 192 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 71848 Ly-a forest pixels from mock 039
# Read in 287 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 79086 Ly-a forest pixels from mock 040
# Read in 309 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 76446 Ly-a forest pixels from mock 041
# Read in 302 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 81301 Ly-a forest pixels from mock 042
# Read in 313 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 77615 Ly-a forest pixels from mock 043
# Read in 313 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 70993 Ly-a forest pixels from mock 044
# Read in 276 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 190 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 76932 Ly-a forest pixels from mock 045
# Read in 273 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 190 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 77082 Ly-a forest pixels from mock 046
# Read in 272 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 190 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 72858 Ly-a forest pixels from mock 047
# Read in 250 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 175 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 73497 Ly-a forest pixels from mock 048
# Read in 270 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 189 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 74604 Ly-a forest pixels from mock 049
# Read in 295 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 188 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 75678 Ly-a forest pixels from mock 050
# Read in 280 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 192 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 72561 Ly-a forest pixels from mock 051
# Read in 257 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 186 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 73766 Ly-a forest pixels from mock 052
# Read in 276 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 188 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 73457 Ly-a forest pixels from mock 053
# Read in 308 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 71769 Ly-a forest pixels from mock 054
# Read in 226 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 177 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 74541 Ly-a forest pixels from mock 055
# Read in 275 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 80501 Ly-a forest pixels from mock 056
# Read in 266 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 186 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 68505 Ly-a forest pixels from mock 057
# Read in 278 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 189 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 77469 Ly-a forest pixels from mock 058
# Read in 299 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 193 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 72544 Ly-a forest pixels from mock 059
# Read in 305 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 193 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 75676 Ly-a forest pixels from mock 060
# Read in 269 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 187 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 70885 Ly-a forest pixels from mock 061
# Read in 298 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 192 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 74424 Ly-a forest pixels from mock 062
# Read in 275 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 189 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 75394 Ly-a forest pixels from mock 063
# Read in 275 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 192 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 69624 Ly-a forest pixels from mock 064
# Read in 276 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 71120 Ly-a forest pixels from mock 065
# Read in 311 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 69316 Ly-a forest pixels from mock 066
# Read in 298 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 79962 Ly-a forest pixels from mock 067
# Read in 239 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 180 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 75191 Ly-a forest pixels from mock 068
# Read in 287 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 74360 Ly-a forest pixels from mock 069
# Read in 304 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 78749 Ly-a forest pixels from mock 070
# Read in 250 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 189 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 76393 Ly-a forest pixels from mock 071
# Read in 277 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 190 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 75267 Ly-a forest pixels from mock 072
# Read in 277 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 184 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 80558 Ly-a forest pixels from mock 073
# Read in 301 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 73060 Ly-a forest pixels from mock 074
# Read in 285 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 193 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 71599 Ly-a forest pixels from mock 075
# Read in 308 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 73661 Ly-a forest pixels from mock 076
# Read in 278 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 189 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 70925 Ly-a forest pixels from mock 077
# Read in 300 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 193 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 72794 Ly-a forest pixels from mock 078
# Read in 306 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 74439 Ly-a forest pixels from mock 079
# Read in 296 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 194 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
# Read in 77635 Ly-a forest pixels from mock 080
# Read in 300 3D-HST galaxies, 506 zCOSMOS-Deep galaxies, 192 MOSDEF galaxies,434 VUDS galaxies, 164 CLAMATO galaxies
